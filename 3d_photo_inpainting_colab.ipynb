# %% [markdown]
# <a href="https://colab.research.google.com/github/jerry727/LibreTV/blob/main/3d_photo_inpainting_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt -y install -qq aria2 xvfb

# !pip install vispy transforms3d networkx
# %cd /content/
# !git clone -b v1.0 https://github.com/camenduru/3d-photo-inpainting
# %cd /content/3d-photo-inpainting
# !git clone -b v1.0 https://github.com/camenduru/BoostingMonocularDepth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/3d-photo-inpainting/resolve/main/color-model.pth -d /content/3d-photo-inpainting/checkpoints -o color-model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/3d-photo-inpainting/resolve/main/depth-model.pth -d /content/3d-photo-inpainting/checkpoints -o depth-model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/3d-photo-inpainting/resolve/main/edge-model.pth -d /content/3d-photo-inpainting/checkpoints -o edge-model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/3d-photo-inpainting/resolve/main/model.pt -d /content/3d-photo-inpainting/checkpoints -o model.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/3d-photo-inpainting/resolve/main/latest_net_G.pth -d /content/3d-photo-inpainting/BoostingMonocularDepth/pix2pix/checkpoints/mergemodel -o latest_net_G.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/3d-photo-inpainting/resolve/main/model-f46da743.pt -d /content/3d-photo-inpainting/BoostingMonocularDepth/midas -o model.pt
# Out:
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# ...

# %%
import os

# First, let's find the file that contains the RankWarning filter.
# It seems the file 'run.py' is not at the assumed location.
# We will use grep to search for the relevant line within the project directory.

print("Searching for 'warnings.simplefilter(\'ignore\', np.RankWarning)' in /content/3d-photo-inpainting...")
# Use !grep to search for the problematic line across all files in the directory
# -r: recursively search subdirectories
# -l: only print the names of files containing matches
# -F: interpret PATTERN as a list of fixed strings, separated by newlines, any of which is to be matched
# -A 0: print 0 lines of trailing context
# !grep -r -l -F "warnings.simplefilter('ignore', np.RankWarning)" /content/3d-photo-inpainting

# After finding the correct file, you would update `file_path` accordingly
# For now, we will comment out the original file patching logic until the correct file is found.
# file_path = '/content/3d-photo-inpainting/BoostingMonocularDepth/run.py'

# # Read the content of the file
# with open(file_path, 'r') as f:
#     lines = f.readlines()

# # Modify the specific line
# new_lines = []
# patched = False
# for line in lines:
#     if "warnings.simplefilter('ignore', np.RankWarning)" in line:
#         new_lines.append(f"# {line.strip()} # Patched by Colab Agent\n")
#         patched = True
#     else:
#         new_lines.append(line)

# # Write the modified content back to the file
# if patched:
#     with open(file_path, 'w') as f:
#         f.writelines(new_lines)
#     print(f"Successfully patched: {file_path}. The line 'warnings.simplefilter(\'ignore\', np.RankWarning)' has been commented out.")
# else:
#     print(f"The target line was not found in {file_path}. No patch applied.")
# Out:
# Searching for 'warnings.simplefilter('ignore', np.RankWarning)' in /content/3d-photo-inpainting...
# /content/3d-photo-inpainting/BoostingMonocularDepth/run.py
# /content/3d-photo-inpainting/BoostingMonocularDepth/demo.py

# %% [markdown]
# 檔案修補完成後，您可以重新執行之前的程式碼單元（`sJpiST0fqxZf`），看看問題是否已解決。

# %%
# %cd /content/3d-photo-inpainting
# !xvfb-run -s "-screen 0 1280x720x24" python main.py --config argument.yml
# Out:
# /content/3d-photo-inpainting
# /content/3d-photo-inpainting/main.py:7: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   import scipy.misc as misc
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ...

# %%
import os

file_path = '/content/3d-photo-inpainting/BoostingMonocularDepth/run.py'

# Read the content of the file
with open(file_path, 'r') as f:
    lines = f.readlines()

# Modify the specific line by commenting it out
new_lines = []
patched = False
for line in lines:
    if "warnings.simplefilter('ignore', np.RankWarning)" in line:
        new_lines.append(f"# {line.strip()} # Patched by Colab Agent\n")
        patched = True
    else:
        new_lines.append(line)

# Write the modified content back to the file
if patched:
    with open(file_path, 'w') as f:
        f.writelines(new_lines)
    print(f"Successfully patched: {file_path}. The line 'warnings.simplefilter(\'ignore\', np.RankWarning)' has been commented out.")
else:
    print(f"The target line was not found in {file_path}. No patch applied.")

# %%
import os
from google.colab import files

input_dir = '/content/3d-photo-inpainting/BoostingMonocularDepth/inputs/'

# Create the directory if it doesn't exist
os.makedirs(input_dir, exist_ok=True)

print(f"請上傳您的 .jpg 圖片到 {input_dir}")
uploaded = files.upload()

for filename in uploaded.keys():
    # Move the uploaded file to the input directory
    os.rename(filename, os.path.join(input_dir, filename))
    print(f'已將檔案 {filename} 移動到 {input_dir}')

print("圖片上傳完成，您可以重新執行主程式了。")

# %% [markdown]
# 圖片上傳完成後，請再次執行程式碼單元 `sJpiST0fqxZf` 來處理您的圖片。

# %% [markdown]
# 檔案修補完成後，您可以重新執行之前的程式碼單元（`sJpiST0fqxZf`），看看問題是否已解決。
